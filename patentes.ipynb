# %% [markdown]
# <a href="https://colab.research.google.com/github/kami24365/dataset/blob/main/patentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hola. Logré arreglar el problema con la conexión al documento ya funciona normal. (Camila)

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

ruta = '/content/drive/MyDrive/Colab Notebooks/Proyecto Bootcamp/Posibles bases de datos/1-2-1 Patentes Publicadas 2000-2024 General.xlsx'


df_patentes = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Proyecto Bootcamp/Posibles bases de datos/1-2-1 Patentes Publicadas 2000-2024 General.xlsx')
df_patentes
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#             SOLICITUD  Año de Publicación                     Naturaleza  \
# 0            99020335                2000  Patente de Invención Nacional
# 1            99021027                2000  Patente de Invención Nacional
# 2            99021045                2000  Patente de Invención Nacional
# 3            99021049                2000  Patente de Invención Nacional
# 4            99021052                2000  Patente de Invención Nacional
# ...               ...                 ...                            ...
# 53269  NC2024/0018080                2024                    Patente PCT
# 53270  NC2024/0018085                2024                    Patente PCT
# 53271  NC2024/0018086                2024                    Patente PCT
# 53272  NC2024/0018087                2024                    Patente PCT
# ...

# %%
#primeros registro
df_patentes.head(5)
# Out:
#   SOLICITUD  Año de Publicación                     Naturaleza  \
# 0  99020335                2000  Patente de Invención Nacional
# 1  99021027                2000  Patente de Invención Nacional
# 2  99021045                2000  Patente de Invención Nacional
# 3  99021049                2000  Patente de Invención Nacional
# 4  99021052                2000  Patente de Invención Nacional
#
#                        Sector  \
# 0  Electricidad - Electrónica
# 1  Electricidad - Electrónica
# 2  Electricidad - Electrónica
# 3  Electricidad - Electrónica
# 4  Electricidad - Electrónica
#
#                                               Titulo Fecha de publicacion  \
# 0                               DISPOSITIVO ACUSTICO           31/01/2000
# 1  DISPOSITIVO DE PROCESAMIENTO DE IMAGEN, METODO...           31/01/2000
# 2  METODOS Y APARATOS PARA REALIZAR OPERACIONES D...           31/01/2000
# 3                  COMPUTADORA CONECTADA EN POLIGONO           31/01/2000
# ...

# %%
#ultimos registros
df_patentes.tail(10)
# Out:
#             SOLICITUD  Año de Publicación   Naturaleza               Sector  \
# 53264  NC2024/0017492                2024  Patente PCT  Ingeniería mecánica
# 53265  NC2024/0017497                2024  Patente PCT              Química
# 53266  NC2024/0017526                2024  Patente PCT              Química
# 53267  NC2024/0017529                2024  Patente PCT              Química
# 53268  NC2024/0017560                2024  Patente PCT         Instrumentos
# 53269  NC2024/0018080                2024  Patente PCT         Instrumentos
# 53270  NC2024/0018085                2024  Patente PCT  Ingeniería mecánica
# 53271  NC2024/0018086                2024  Patente PCT  Ingeniería mecánica
# 53272  NC2024/0018087                2024  Patente PCT  Ingeniería mecánica
# 53273  NC2024/0018142                2024  Patente PCT         Instrumentos
#
#                                                   Titulo Fecha de publicacion  \
# ...

# %%
df_patentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53274 entries, 0 to 53273
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SOLICITUD             53274 non-null  object
#  1   Año de Publicación    53274 non-null  int64
#  2   Naturaleza            53274 non-null  object
#  3   Sector                52947 non-null  object
#  4   Titulo                53271 non-null  object
#  5   Fecha de publicacion  53274 non-null  object
#  6   Pais                  53273 non-null  object
#  7   Region                43829 non-null  object
#  8   Ciudad                43630 non-null  object
#  9   Solicitante           53270 non-null  object
#  10  Inventor              53250 non-null  object
#  11  Clasificacion         53270 non-null  object
#  12  Residente             53274 non-null  object
#  13  Trámite               53274 non-null  object
#  14  País Nom              53274 non-null  object
# ...

# %%
#mostrar info estadistica
df_patentes.describe()
# Out:
#        Año de Publicación
# count        53274.000000
# mean          2013.284829
# std              6.794660
# min           2000.000000
# 25%           2008.000000
# 50%           2013.000000
# 75%           2019.000000
# max           2024.000000

# %%
#cantifad  filas y columnas

df_patentes.shape
# Out:
# (53274, 16)

# %%
#nombres comlumnas
df_patentes.columns
# Out:
# Index(['SOLICITUD', 'Año de Publicación', 'Naturaleza', 'Sector', 'Titulo',
#        'Fecha de publicacion', 'Pais', 'Region', 'Ciudad', 'Solicitante',
#        'Inventor', 'Clasificacion', 'Residente', 'Trámite', 'País Nom',
#        'Vía Presntac'],
#       dtype='object')
